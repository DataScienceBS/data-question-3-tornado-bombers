# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "bomb.png", width=600)
# Out:
# <img src="bomb.png" width="600"/>

# %%
#Importing the html via using BeuatifulSoup.  Alternatively, there is a pandas function pd.read_html('my_html_data').......

import pandas as pd
from bs4 import BeautifulSoup as BS
from urllib import request
import numpy as np

wiki = ('https://en.wikipedia.org/wiki/List_of_deadly_earthquakes_since_1900')
result = request.urlopen(wiki)
soup = BS(result.read(), 'html.parser')
t = soup.find_all(class_='wikitable')[0]
df = pd.read_html(str(t), header=0)[0]

print(df)

'''trs = table.find_all('tr')

header = trs.pop(0)
ths = header.find_all('th')

headers = [x.text for x in ths]
data = []

for row in trs:
    tds = row.find_all('td')
    data.append([f.text for f in tds])
    
df = pd.DataFrame.from_records(data, columns=headers)'''
# Out:
#           Origin (UTC) Present-day country and link to Wikipedia article  \
# 0     1900-05-11 17:23                                             Japan
# 1     1900-07-12 06:25                                            Turkey
# 2     1900-10-29 09:11                                         Venezuela
# 3     1901-02-15 00:00                                             China
# 4     1901-03-31 07:11                                          Bulgaria
# 5     1901-08-09 09:23                                             Japan
# 6     1901-11-15 20:15         New Zealand (see 1901 Cheviot earthquake)
# 7     1902-01-30 14:01                                             Japan
# 8     1902-02-13 09:39                                        Azerbaijan
# 9     1902-03-09 07:46                                            Turkey
# 10    1902-04-19 02:23         Guatemala (see 1902 Guatemala earthquake)
# 11    1902-07-03 15:36                                             China
# ...

# %%
# Making sure we're working with the correct number of columns and rows in our dataframe.  

print(type(df))
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (1340, 12)

# %%
# (1) Pandas automatically fills empty strings with 'NaN' noted below.   

df.head(15)
# Out:
#         Origin (UTC) Present-day country and link to Wikipedia article  \
# 0   1900-05-11 17:23                                             Japan
# 1   1900-07-12 06:25                                            Turkey
# 2   1900-10-29 09:11                                         Venezuela
# 3   1901-02-15 00:00                                             China
# 4   1901-03-31 07:11                                          Bulgaria
# 5   1901-08-09 09:23                                             Japan
# 6   1901-11-15 20:15         New Zealand (see 1901 Cheviot earthquake)
# 7   1902-01-30 14:01                                             Japan
# 8   1902-02-13 09:39                                        Azerbaijan
# 9   1902-03-09 07:46                                            Turkey
# 10  1902-04-19 02:23         Guatemala (see 1902 Guatemala earthquake)
# 11  1902-07-03 15:36                                             China
# ...

# %%
df.tail(15)
# Out:
#           Origin (UTC) Present-day country and link to Wikipedia article  \
# 1325  2009-09-02 07:55         Indonesia (see 2009 West Java earthquake)
# 1326  2009-09-29 17:48     Samoa (see 2009 Samoa earthquake and tsunami)
# 1327  2009-09-30 10:16            Indonesia (see 2009 Padang earthquake)
# 1328  2010-01-12 17:00                 Haiti (see 2010 Haiti earthquake)
# 1329  2010-02-27 06:34                 Chile (see 2010 Chile earthquake)
# 1330  2010-03-08 02:32               Turkey (see 2010 Elâzığ earthquake)
# 1331  2010-03-11 14:39             Chile (see 2010 Pichilemu earthquake)
# 1332  2010-04-14 23:49                 China (see 2010 Yushu earthquake)
# 1333  2011-02-21 23:51    New Zealand (see 2011 Christchurch earthquake)
# 1334  2011-03-10 04:58                China (see 2011 Yunnan earthquake)
# 1335  2011-03-11 14:46                Japan (see 2011 Tōhoku earthquake)
# 1336  2011-03-24 20:25                 Burma (see 2011 Burma earthquake)
# ...

# %%
# (2) Dropping the footnotes from 'Other Source Deaths' and cleaning up the 'EM-DAT Total Deaths' columns.  

pattern = r'\(.*\)|\[.*\]|\D'
df['Other Source Deaths'] = df['Other Source Deaths'].str.replace(pattern,"")
df['EM-DAT Total Deaths'] = df['EM-DAT Total Deaths'].str.replace(pattern, "")
df.tail(15)
# Out:
#           Origin (UTC) Present-day country and link to Wikipedia article  \
# 1325  2009-09-02 07:55         Indonesia (see 2009 West Java earthquake)
# 1326  2009-09-29 17:48     Samoa (see 2009 Samoa earthquake and tsunami)
# 1327  2009-09-30 10:16            Indonesia (see 2009 Padang earthquake)
# 1328  2010-01-12 17:00                 Haiti (see 2010 Haiti earthquake)
# 1329  2010-02-27 06:34                 Chile (see 2010 Chile earthquake)
# 1330  2010-03-08 02:32               Turkey (see 2010 Elâzığ earthquake)
# 1331  2010-03-11 14:39             Chile (see 2010 Pichilemu earthquake)
# 1332  2010-04-14 23:49                 China (see 2010 Yushu earthquake)
# 1333  2011-02-21 23:51    New Zealand (see 2011 Christchurch earthquake)
# 1334  2011-03-10 04:58                China (see 2011 Yunnan earthquake)
# 1335  2011-03-11 14:46                Japan (see 2011 Tōhoku earthquake)
# 1336  2011-03-24 20:25                 Burma (see 2011 Burma earthquake)
# ...

# %%
# (3) Converting Magnitude to numeric by removing the 'Mv.' 

pattern = r'([^\.\d]).*'
df['Magnitude'] = df['Magnitude'].str.replace(pattern, "")
df.head(15)
# Out:
#         Origin (UTC) Present-day country and link to Wikipedia article  \
# 0   1900-05-11 17:23                                             Japan
# 1   1900-07-12 06:25                                            Turkey
# 2   1900-10-29 09:11                                         Venezuela
# 3   1901-02-15 00:00                                             China
# 4   1901-03-31 07:11                                          Bulgaria
# 5   1901-08-09 09:23                                             Japan
# 6   1901-11-15 20:15         New Zealand (see 1901 Cheviot earthquake)
# 7   1902-01-30 14:01                                             Japan
# 8   1902-02-13 09:39                                        Azerbaijan
# 9   1902-03-09 07:46                                            Turkey
# 10  1902-04-19 02:23         Guatemala (see 1902 Guatemala earthquake)
# 11  1902-07-03 15:36                                             China
# ...

# %%
#Converting everything to numeric type values.  

df['Magnitude'] = pd.to_numeric(df['Magnitude'])
df['Other Source Deaths'] = pd.to_numeric(df['Other Source Deaths'])
df['EM-DAT Total Deaths'] = pd.to_numeric(df['EM-DAT Total Deaths'])

# %%
# (4) Creating a new column ('deaths') that evaluates the four total-death columns ('PDE Total Deaths', 'Utsu Total Deaths', 'EM-DAT Total Deaths', and 'Other Source Deaths') and populates the new column with the highest value.

df['Deaths'] = df[['PDE Total Deaths', 'EM-DAT Total Deaths', 'Utsu Total Deaths', 'Other Source Deaths']].max(axis=1)
df.head(15)
# Out:
#         Origin (UTC) Present-day country and link to Wikipedia article  \
# 0   1900-05-11 17:23                                             Japan
# 1   1900-07-12 06:25                                            Turkey
# 2   1900-10-29 09:11                                         Venezuela
# 3   1901-02-15 00:00                                             China
# 4   1901-03-31 07:11                                          Bulgaria
# 5   1901-08-09 09:23                                             Japan
# 6   1901-11-15 20:15         New Zealand (see 1901 Cheviot earthquake)
# 7   1902-01-30 14:01                                             Japan
# 8   1902-02-13 09:39                                        Azerbaijan
# 9   1902-03-09 07:46                                            Turkey
# 10  1902-04-19 02:23         Guatemala (see 1902 Guatemala earthquake)
# 11  1902-07-03 15:36                                             China
# ...

# %%
#Renaming the 'Country' and 'Origin' columns and removing the additional strings in the Country column. 

df.rename(columns={'Present-day country and link to Wikipedia article':'Country'}, inplace=True)
df.rename(columns={'Origin (UTC)':'Year'}, inplace=True)
df.head(15)
# Out:
#                 Year                                    Country      Lat  \
# 0   1900-05-11 17:23                                      Japan   38.700
# 1   1900-07-12 06:25                                     Turkey   40.300
# 2   1900-10-29 09:11                                  Venezuela   11.000
# 3   1901-02-15 00:00                                      China   26.000
# 4   1901-03-31 07:11                                   Bulgaria   43.400
# 5   1901-08-09 09:23                                      Japan   40.500
# 6   1901-11-15 20:15  New Zealand (see 1901 Cheviot earthquake)  -43.000
# 7   1902-01-30 14:01                                      Japan   40.500
# 8   1902-02-13 09:39                                 Azerbaijan   40.700
# 9   1902-03-09 07:46                                     Turkey   40.700
# 10  1902-04-19 02:23  Guatemala (see 1902 Guatemala earthquake)   14.000
# 11  1902-07-03 15:36                                      China   43.200
# ...

# %%
#It looks like we missed some spaces behind our countries.  

list(set(df['Country']))
# Out:
# ['Democratic Republic of the Congo (see 2008 Lake Kivu earthquake)',
#  'Italy (see 2002 Molise earthquake)',
#  'China (see 1974 Zhaotong earthquake)',
#  'Morocco (see 1960 Agadir earthquake)',
#  'Canada',
#  'Mexico (see 1980 Oaxaca earthquake)',
#  'France (see 1909 Provence earthquake)',
#  'Pakistan (see 1935 Quetta earthquake)',
#  'Turkey (see 1976 Çaldıran–Muradiye earthquake)',
#  'Turkey (see 1999 Düzce earthquake)',
#  'Azerbaijan (see 2000 Baku earthquake)',
#  'Turkey (see 1914 Burdur earthquake)',
#  'Indonesia (see March 2007 Sumatra earthquakes)',
#  'Saudi Arabia/Egypt (see 1995 Gulf of Aqaba earthquake)',
#  'China (see 1970 Tonghai earthquake)',
#  'Malawi (see 1989 Malawi earthquake)',
#  'Kazakhstan',
#  'Indonesia (see 1976 Papua earthquake)',
#  'Japan',
#  'Iran (see 1997 Qayen earthquake)',
#  'Taiwan (see 1916–17 Nantou earthquakes',
#  'Burma',
#  'Turkey (see 1971 Bingöl earthquake)',
#  'Turkey (see 1903 Manzikert earthquake)',
# ...

# %%
#The Set list looks correct now for all our countries.  

pattern = r'(, ?| ?\().*'
df['Country'] = df['Country'].str.replace(pattern, "")
list(set(df['Country']))
# Out:
# ['',
#  'Uzbekistan',
#  'Netherlands',
#  'Wallis and Futuna',
#  'Turkmenistan',
#  'Serbia',
#  'Canada',
#  'Ghana',
#  'Italy',
#  'Mongolia',
#  'Mozambique',
#  'Chile',
#  'Iceland',
#  'Spain',
#  'Kazakhstan',
#  'Venezuela',
#  'Mexico',
#  'Japan',
#  'Burma',
#  'Saint Pierre and Miquelon',
#  'Bosnia and Herzegovina',
#  'Dominican Republic',
#  'US Territory of Alaska',
#  'Kingdom of Yugoslavia',
#  'Portugal',
#  'Haiti',
#  'Fiji',
#  'Algeria',
#  'Yemen',
#  'Uganda',
#  'Malawi',
#  'Martinique',
#  'Armenia',
#  'England',
#  'Albania',
#  'China',
#  'Bulgaria',
#  'Ecuador',
#  'Tajikistan',
#  'Mandatory Palestine and Transjordan',
#  'Morocco',
#  'United States Minor Outlying Islands',
#  'Nepal',
#  'Tajik Soviet Socialist Republic',
#  'Montenegro',
#  'Malaysia',
#  'Bangladesh',
#  'Brazil',
#  'Eritrea',
#  'Vanuatu',
#  'Ethiopia',
#  'Hungary',
#  'Honduras',
#  'Afghanistan',
#  'Guatemala',
#  'Georgia',
#  'Puerto Rico',
#  'Czech Republic',
# ...

# %%
#fixing the ?'s in the Lat, Long, and Depth columns for plotting purposes later on and converting these columns to numeric values.  

pattern = r'\?'
df['Long'] = df['Long'].replace(pattern, np.NaN, regex=True)
df['Lat'] = df['Lat'].replace(pattern, np.NaN, regex=True)
df['Depth (km)'] = df['Depth (km)'].replace(pattern, np.NaN, regex=True)
df['Lat'] = pd.to_numeric(df['Lat'])
df['Long'] = pd.to_numeric(df['Long'])
df['Depth (km)'] = pd.to_numeric(df['Depth (km)'])
df.tail(15)
# Out:
#                   Year      Country     Lat     Long  Depth (km)  Magnitude  \
# 1325  2009-09-02 07:55    Indonesia     NaN      NaN         NaN        7.0
# 1326  2009-09-29 17:48        Samoa     NaN      NaN         8.1        8.1
# 1327  2009-09-30 10:16    Indonesia     NaN      NaN         NaN        7.6
# 1328  2010-01-12 17:00        Haiti  18.457  -72.533        13.0        7.0
# 1329  2010-02-27 06:34        Chile -35.846  -72.719        35.0        8.8
# 1330  2010-03-08 02:32       Turkey     NaN      NaN         NaN        6.1
# 1331  2010-03-11 14:39        Chile     NaN      NaN         NaN        6.9
# 1332  2010-04-14 23:49        China     NaN      NaN         NaN        6.9
# 1333  2011-02-21 23:51  New Zealand     NaN      NaN         NaN        6.3
# 1334  2011-03-10 04:58        China     NaN      NaN         NaN        5.4
# 1335  2011-03-11 14:46        Japan  38.322  142.369        24.4        9.0
# ...

# %%
# (5) Explore the data in terms of when and where earthquakes occurred and how severe they were (magnitude, deaths, secondary effects

import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point
import seaborn as sns
# %matplotlib inline
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
def make_point(row):
    return Point(row.Long, row.Lat)
points = df.apply(make_point, axis=1)
quakes = gpd.GeoDataFrame(df, geometry=points)
quakes.crs = {'init': 'epsg:4326'}
ax = world.plot(color='black', edgecolor='white', figsize=(25,255))
ax.axis('off')
quakes.plot(ax=ax, marker='*', color='red', markersize=8);

# %%
#Working on adding tectonic plate boundaires to our world map to help answer the question "where?".  

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
def make_point(row):
    return Point(row.Long, row.Lat)
points = df.apply(make_point, axis=1)
quakes = gpd.GeoDataFrame(df, geometry=points)
quakes.crs = {'init': 'epsg:4326'}
ax = world.plot(color='black', edgecolor='white', figsize=(25,255))
ax.axis('on')
quakes.plot(ax=ax, marker='*', color='red', markersize=8)
boundaries.plot(ax=ax, color='blue', markersize=8)

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
from IPython.display import display, clear_output
import traitlets
import warnings
import ipywidgets as widgets
from IPython.display import display, clear_output

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
geometry = [Point(x) for x in zip(quakes["Long"], quakes["Lat"])]
gdf = gpd.GeoDataFrame(quakes, geometry=geometry)

countries = sorted(list(set(gdf.Country)))
countries.insert(0, 'ALL')
countries.remove("")

w = widgets.FloatRangeSlider(value=(0,10), min=0, max=10, continuous_update=False, description='Magnitude')
m = widgets.Dropdown(options=countries, value='ALL', description='Country', disabled=False,)
z = widgets.HBox([w,m])
display(z)

ax = world.plot(color='#cfd1d3', edgecolor='black', figsize=(25,55))
ax.axis('off')
gdf.plot(ax=ax, column='Magnitude', alpha=0.4, cmap='seismic', );
fig = ax.get_figure()

divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='3%', pad=0.01)

sm = plt.cm.ScalarMappable(cmap='seismic', norm=plt.Normalize(vmin=2.0, vmax=10.0))
sm._A = []
fig.colorbar(sm,cax=cax)
fig.patch.set_facecolor('#e4f4ff')

maximum = 10
minimum = 0
country = "ALL"
world_copy = world.copy()

def response(change):
    try:
        clear_output(wait=True)
        global country
        global maximum
        global minimum
        global world_copy
        if len(change['new']) == 2:
            maximum = change['new'][1]
            minimum = change['new'][0]
        else:
            country = change['new']
        display(z)

        if country.upper() == 'ALL':
            display_df = gdf[(gdf["Magnitude"] >= minimum) & (gdf['Magnitude'] <= maximum)]
            world_copy = world
        else:
            display_df = gdf[(gdf["Magnitude"] >= minimum) & (gdf['Magnitude'] <= maximum) & (gdf['Country'].str.upper() == country.upper())]
            world_copy = world[world['name'].str.upper() == country.upper()]

        #display_df = gdf[(gdf["Magnitude"] >= minimum) & (gdf['Magnitude'] <= maximum)]


        ax = world_copy.plot(color='#cfd1d3', edgecolor='black', figsize=(25,55))
        ax.axis('off')
        display_df.plot(ax=ax, column='Magnitude', alpha=0.4, cmap='seismic', );
        fig = ax.get_figure()

        divider = make_axes_locatable(ax)
        cax = divider.append_axes('right', size='3%', pad=0.01)

        sm = plt.cm.ScalarMappable(cmap='seismic', norm=plt.Normalize(vmin=2.0, vmax=10.0))
        sm._A = []
        fig.colorbar(sm,cax=cax)
        fig.patch.set_facecolor('#e4f4ff')
    except:
        print("Ain't no earthquakes of this magnitude in this country... Try again")
        warnings.filterwarnings('ignore')

    
w.observe(response, names='value')
m.observe(response, names='value')
# Out:
# A Jupyter Widget

# %%
import folium

new_map = folium.Map(location=[43.1,40.3], zoom_start=2)

for row in gdf.iterrows():
    row = list(row[1])
    try:
        folium.Marker([row[2],row[3]], popup=str(row[1]) + ' | ' + str(row[0]) + ' | ' + str(row[5])).add_to(new_map)
    except:
        continue
   
new_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Slicing just the first four characters of the Date column for graphing purposes.  

quakes['Year'] = quakes['Year'].str[:4]
quakes.sort_values(by= 'Deaths', ascending=False).head(10)
# Out:
#       Year       Country     Lat     Long  Depth (km)  Magnitude  \
# 583   1976         China  39.605  117.888        16.7        7.6
# 1238  2004     Indonesia   3.287   95.972        30.0        9.1
# 102   1920         China  36.601  105.317        25.0        8.6
# 1328  2010         Haiti  18.457  -72.533        13.0        7.0
# 140   1927         China  37.386  102.311        25.0        7.9
# 116   1923         Japan  35.405  139.084        35.0        7.9
# 302   1948  Turkmenistan  37.500   58.000         0.0        7.2
# 1308  2008         China  31.002  103.322        19.0        7.9
# 1253  2005      Pakistan  34.465   73.584        23.1        7.6
# 41    1908         Italy  38.000   15.500         0.0        7.2
#
#      Secondary Effects  PDE Shaking Deaths  PDE Total Deaths  \
# 583                NaN            655237.0          655237.0
# 1238               T,L                 NaN          297200.0
# 102                NaN                 NaN               NaN
# ...

# %%
quakes['Country'].value_counts(dropna=False)
# Out:
# China                                  166
# Indonesia                               96
# Turkey                                  95
# Iran                                    92
# Japan                                   82
# Peru                                    54
# Taiwan                                  48
# Mexico                                  46
# Greece                                  44
# Chile                                   44
# Philippines                             39
# Italy                                   37
# United States                           34
# Afghanistan                             30
# Pakistan                                26
# India                                   25
# Colombia                                24
# Algeria                                 21
# Ecuador                                 19
# Papua New Guinea                        17
# Guatemala                               15
# South Africa                            14
# ...

# %%
quakes['Deaths'].nlargest(10)
# Out:
# 583     655237.0
# 1238    297200.0
# 102     235502.0
# 1328    222517.0
# 140     200000.0
# 116     143000.0
# 302     110000.0
# 1308     88287.0
# 1253     87351.0
# 41       82000.0
# Name: Deaths, dtype: float64

# %%
quakes['Magnitude'].nlargest(10)
# Out:
# 396     9.5
# 416     9.2
# 1238    9.1
# 332     9.0
# 1335    9.0
# 29      8.8
# 1329    8.8
# 109     8.7
# 102     8.6
# 318     8.6
# Name: Magnitude, dtype: float64

# %%
mag_dep = quakes.groupby(['Magnitude','Depth (km)'])['Deaths'].sum()
mag_dep=mag_dep.reset_index()
mag_dep
plt.title('World Magnitude by Depth (km) Comparison')
plt.xlabel('Magnitude')
plt.ylabel('Depth (km)')
plt.scatter(mag_dep['Magnitude'],mag_dep['Depth (km)'], marker='.', alpha=0.5, edgecolors='purple')

# %%
deaths_mag = quakes.groupby(['Magnitude','Deaths'])['Depth (km)'].sum()
deaths_mag = mag_dep.reset_index()
deaths_mag
plt.title('Wrold Deaths by Magnitude')
plt.xlabel('Magnitude')
plt.ylabel('Number of Deaths')
plt.scatter(deaths_mag['Magnitude'],deaths_mag['Depth (km)'], marker='.', alpha=0.5, edgecolors='yellow')

# %%
plt.hist(quakes['Magnitude'].dropna(), bins=25, color='blue')
plt.title("Magnitude Frequency since 1990")
plt.xlabel("Magnitude")
# Out:
# Text(0.5,0,'Magnitude')

# %%
plt.hist(quakes['Depth (km)'].dropna(), bins=10, color='green')
plt.title("Depth (km) Frequency since 1990")
plt.xlabel("Depth (km)")
# Out:
# Text(0.5,0,'Depth (km)')

# %%
USA = quakes.loc[quakes['Country'] == 'United States']
China = quakes.loc[quakes['Country'] == 'China']
USA['Magnitude'].nlargest(10)
# Out:
# 416    9.2
# 32     7.8
# 278    7.3
# 328    7.3
# 387    7.3
# 922    7.3
# 233    6.9
# 726    6.9
# 850    6.9
# 93     6.8
# Name: Magnitude, dtype: float64

# %%
USA_largest = USA.loc[USA['Magnitude'].isin([9.2,7.8,7.3,6.9, 6.9])]
print(USA_largest)
# Out:
#      Year        Country     Lat     Long  Depth (km)  Magnitude  \
# 32   1906  United States  38.000 -123.000         0.0        7.8
# 233  1940  United States  33.222 -115.697        15.0        6.9
# 278  1946  United States  52.750 -163.500         0.0        7.3
# 328  1952  United States  34.949 -119.046        10.0        7.3
# 387  1959  United States  44.548 -110.636        15.0        7.3
# 416  1964  United States  61.017 -147.648         6.6        9.2
# 726  1983  United States  44.078 -113.800        16.0        6.9
# 850  1989  United States  37.110 -121.764        16.0        6.9
# 922  1992  United States  34.190 -116.520        15.0        7.3
#
#     Secondary Effects  PDE Shaking Deaths  PDE Total Deaths  \
# 32                  F                 NaN               NaN
# 233               NaN                 NaN               NaN
# 278                 T                 NaN               NaN
# 328               NaN                 NaN               NaN
# ...

# %%
plt.scatter(USA['Year'], USA['Deaths'], marker='.', alpha=0.5)
plt.title('USA Deaths by Quakes over time')
plt.xlabel('Year')
plt.ylabel('Deaths')
# Out:
# Text(0,0.5,'Deaths')

# %%
plt.hist(USA ['Deaths'], bins=35)
plt.title('Frequency of Deaths by Earthquakes in the USA')
plt.xlabel('Deaths')
# Out:
# Text(0.5,0,'Deaths')

# %%
plt.hist(USA['Magnitude'], bins=35)
plt.title('USA Magnitude Frequencies')
plt.xlabel('Magnitude')
# Out:
# Text(0.5,0,'Magnitude')

# %%
#USA_map = gpd.read_file('USA_adm0.shp')
#USA_ax = USA_map.plot(color='black', edgecolor='white', figsize=(25,255))
#USA_ax.axis('off')

# %%
plot_year_death = quakes.copy() #copy the original df for this specific plot
years = sorted(list(set(plot_year_death['Year']))) #make unique list of years, ascending
plot_year_death = plot_year_death.loc[plot_year_death['Year']==years[-1]] #years[-1] chooses most recent year for display

plt.title('Deaths by year sized by magnitude for ' + years[-1]) #display year selection in title
plt.xticks(rotation='vertical')
plt.scatter(plot_year_death['Country'], plot_year_death['Deaths'], marker='*', alpha=0.3, s=plot_year_death['Magnitude']**3, edgecolor='red')

d = widgets.Dropdown(
    options=years,
    value=years[-1],  # using -1 defaults to the most recent year of unique years list
    description='Year',
    disabled=False,
)
display(d)

def plot_y(y_change):
    clear_output()
    year = y_change['new']
    plot_year_death = quakes.copy() 
    plot_year_death = plot_year_death.loc[plot_year_death['Year']==year] #new df with year selected
    display(d)
    plt.title('Deaths by country sized by magnitude for ' + year) #display year selection in title
    plt.xticks(rotation='vertical')
    plt.scatter(plot_year_death['Country'], plot_year_death['Deaths'], marker='*', alpha=0.3, s=plot_year_death['Magnitude']**3, edgecolor='red')

d.observe(plot_y, names='value')
# Out:
# A Jupyter Widget

# %%
quakes_1 = quakes[(quakes['Magnitude'] >= 8.4) & (quakes['Magnitude'] <= 10.0)]

# %%
quakes_1.count()
# Out:
# Year                   15
# Country                15
# Lat                    15
# Long                   15
# Depth (km)             15
# Magnitude              15
# Secondary Effects      14
# PDE Shaking Deaths      3
# PDE Total Deaths        4
# Utsu Total Deaths       8
# EM-DAT Total Deaths     9
# Other Source Deaths     3
# Deaths                 13
# geometry               15
# dtype: int64

# %%
f_1 = quakes[(quakes['Country'] == 'China') | (quakes['Country'] == 'Turkey') | (quakes['Country'] == 'Peru') | (quakes['Country'] == 'United States') | (quakes['Country'] == 'Japan')]
f_1.count()
# Out:
# Year                   431
# Country                431
# Lat                    425
# Long                   425
# Depth (km)             391
# Magnitude              431
# Secondary Effects       94
# PDE Shaking Deaths     198
# PDE Total Deaths       196
# Utsu Total Deaths      340
# EM-DAT Total Deaths    170
# Other Source Deaths     14
# Deaths                 409
# geometry               431
# dtype: int64

# %%
import seaborn as sns

c = sns.FacetGrid(f_1, col= "Country", hue= "Country", size=5.0)
c.map(plt.plot, "Magnitude", "Deaths", marker= ".")
plt.show()

# %%
c = sns.FacetGrid(f_1, col= "Country", hue= "Country", size=5.0)
c.map(plt.plot, "Year", "Magnitude", marker= ".")
plt.show()
